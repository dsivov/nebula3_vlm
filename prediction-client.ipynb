# %%
import requests
import json




data = { "signature_name": "serving_clip", "instances": { "text": "dima text", "movie_id": "Movies/114208744", "scene_element": 1 } }
session = requests.Session()

for i in range(10):
    predictions = session.post(
        'https://df3126b4a460d4f0ba2787d7e662c6f9a.clg07azjl.paperspacegradient.com/v1/models/clip_ms:encode_text',
        json=data
    )

#predictions = json.loads(predictions.text)[0]

    print(predictions.text)
# Out:
# {"clip_data": {"text": "dima text", "movie_id": "Movies/114208744", "scene_element": 1}, "clip_vector": [0.033547043800354004, 0.018648583441972733, -0.0028961768839508295, -0.022060809656977654, 0.007116028107702732, -0.007885799743235111, -0.003928587771952152, -0.03218875825405121, 0.0012458990095183253, -0.0039012678898870945, 0.016396673396229744, 0.0056718201376497746, -0.003514117794111371, -0.011175735853612423, -0.0014400426298379898, -0.04763637110590935, -0.0025307005271315575, 0.006419741082936525, -0.0014149911003187299, -0.012941119261085987, -0.008840157650411129, -0.012184098362922668, -0.00949913077056408, -0.013355236500501633, 0.013378100469708443, -0.005681113805621862, -0.0161920003592968, -0.016226431354880333, 0.018632126972079277, 0.0067252409644424915, -0.00702957296743989, 0.012971707619726658, -0.007921417243778706, 0.016580840572714806, 0.012498262338340282, -0.01049805711954832, 0.003574787639081478, -0.007099004462361336, 0.0015819736290723085, 0.0143874
# ...
